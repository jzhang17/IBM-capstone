# %%
# The code was removed by DSX for sharing.

# %%
from io import BytesIO
import zipfile

zip_ref = zipfile.ZipFile(BytesIO(streaming_body_1.read()), 'r')
print(zip_ref.namelist()[:70])
zip_ref.extractall('r/')
zip_ref.close()
# Out:
# ['48dQAKGF1hhYUJkrnpIMAz.html', '1DM3q41KgvMA1RlkS5okLE.html', '76S7Bhs0Tl26LGqtKNO3Fu.html', '2Du1691rCtSYlNZDZZBgy9.json', '7F48uN3iimqr7iJoa66kBu.html', '5YpLD7MKPt05e0w2n0X5C5.json', '740IEuqP9LfAyA5lRuVYPV.json', '7ohmd5Xgn8vzchFk6gvnVp.json', '3yZz70dQGZ3dc47YDZlptD.html', '2ezgBu2nHWuZOmfCxwquF0.json', '2vc2YIhLNzc3qXgIbOMsnQ.html', '6fWjEzKlQziJt8uo5m4y8F.json', '5fwDo5dpOc1R9BN6CueUWY.json', '38G1cFwgeuWx8DMjrWjgnc.html', '6XS7m8j7h6uYbueXiERyfF.html', '4eZvT0pHG6CUFaf7htBAlN.json', '3iMxbJ2hpgtpmjcxo8s2SP.html', '7IfhTZREUEZGsvMPXtpfiK.json', '2scgHbVk3GieaSg5DsuWcV.html', '1UNcn2f5rdWaZVvOBZ4ack.html', '4bEs5Pw27qILl0XN4UfHdC.json', '4zwwQS1CLWJOFE1J0Szkfu.json', '4IHnFkGTPIBeRQHNyVVn3l.json', '2akMLJjZ3a6W6jMxLgYOC4.html', 'b7V096G3vsGOuACPIjSRO.html', '5WoF4ofdOseXAkgT67cuAf.json', '4snxk5yUPs0gw4fTUIJvWo.html', '2xn7TXGp17ChGD2KAvI1iw.html', '7zCIz6MF51u9dvPeh9OBYc.html', '6FoTfeX1RQOOjYeb2u7gt4.json', '1K16pBSljiZrfzp83ok7Qj.html', '1b9wvDL5zH1YCATdsTypIV.html', '2PHCi
# ...

# %%
import os, json
import pandas as pd

path_to_json = 'r/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
print(json_files[:70])
# Out:
# ['iMhK6V4iwNRfo3XS6A5nD.json', '7LIP7ctmEdORuMhAMrY3NP.json', '4sYkpkx0xe7tFJmbWpOUMa.json', '21sz86CGVA1u4VipDy0Z5w.json', '1nPU3SpQ2UA3A1cCvu7XKw.json', 'YJYhkMWN3f4FNxfRusQUS.json', '5CGnk3SjXciQbKRko8J8iL.json', '1yi0OghlNz9oj27VNROuXe.json', '4CYswtA8bax7aqTzHKyMCp.json', '5Yn9rBIbVbPyDqFkvekEoG.json', '7Cl6wl5doXRUVcBt4Vzqty.json', '6p0mtUOqZ0qXtZ4NN7Pj9T.json', '3FJFBY15njYGaH7wAsb8lY.json', '6dEyAbcxPzix1KmaTyJHXW.json', '23aQMaX1mm9ptGySf8g7JG.json', '2ofSwNApMNPDiIrEA0R31p.json', '5i2UvDEieWxpbmb0pWRbe3.json', '501bU2ooRA8Sw59I3u989v.json', '5eanVroIXfYLBOhZxPopi9.json', '1TRB7RKQ1kffebAdm7oQ6o.json', '18YFWDDwcGZ6sTO7zlThIo.json', '3GGKUfY2lnPl4WTTri7jg6.json', '13UaOcNmJiV47p8JynWE0L.json', '2yKMcHkWvpn1shuXrnQ7VL.json', '1jD3wpE4r744vvsonjRb0p.json', '3NsEXpGQAg5Wiei9U2BuEi.json', '1NZy4CJG7kYB0OTQ6daRNE.json', '7nD7GGJu0q1xmzpIBPgJX1.json', 'nRxLlxtI5XwaPJhFzERIp.json', '3bPKgQIAi3KNLdcHbeobvB.json', '6zoREU2UbM3jN5YtsMOH7d.json', 'LeAyNIA0enlFzOuzDCUp9.json', '4QCXs0jr
# ...

# %%
import os, json
import pandas as pd


path_to_json = 'r/'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]


jsons_data = pd.DataFrame(columns=["filing_type", "filing_date", "filename", "company_cik", "doc_type", "filing_id", "company_name", "id"])


for index, js in enumerate(json_files):
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)

        
        filing_type = json_text['filing_type']
        filing_date = json_text['filing_date']
        filename = json_text['filename']
        company_cik = json_text['company_cik']
        doc_type = json_text['doc_type']
        filing_id = json_text['filing_id']
        company_name = json_text['company_name']                           
        id = json_text['id']                           
       
        
        jsons_data.loc[index] = [filing_type, filing_date, filename, company_cik, doc_type, filing_id, company_name, id]

# %%
jsons_data.head()
# Out:
#   filing_type filing_date               filename company_cik doc_type  \
# 0        S-11    20170505    V466088_EX10-48.HTM     1487782    EX-10
# 1       S-1/A    20160902    S103988_EX10-19.HTM     1501432    EX-10
# 2         8-K    20161110  A16-21456_1EX10D1.HTM     1579428    EX-10
# 3        10-Q    20150909       D92513DEX102.HTM       56679    EX-10
# 4        10-Q    20160811      RUN-EX101_912.HTM     1469367    EX-10
#
#               filing_id               company_name                      id
# 0  0001144204-17-024799   Reven Housing REIT, Inc.   iMhK6V4iwNRfo3XS6A5nD
# 1  0001615774-16-007047         Full Spectrum Inc.  7LIP7ctmEdORuMhAMrY3NP
# 2  0001104659-16-156253  Axsome Therapeutics, Inc.  4sYkpkx0xe7tFJmbWpOUMa
# 3  0001193125-15-315902   KORN FERRY INTERNATIONAL  21sz86CGVA1u4VipDy0Z5w
# 4  0001564590-16-024098                Sunrun Inc.  1nPU3SpQ2UA3A1cCvu7XKw

# %%
from IPython.display import HTML
import base64
def create_download_link(jsons_data, title = "Download CSV file", filename = "data.csv"):  
    csv = jsons_data.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(jsons_data)
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
